# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
from kaggle_secrets import UserSecretsClient
secret_label = "your-secret-label"
secret_value = UserSecretsClient().get_secret(secret_label)

for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import os
from kaggle_secrets import UserSecretsClient

try:
    GOOGLE_API_KEY = UserSecretsClient().get_secret("GOOGLE_API_KEY")
    os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY
    os.environ["GOOGLE_GENAI_USE_VERTEXAI"] = "FALSE"
    print("✅ Gemini API key setup complete.")
except Exception as e:
    print(f"🔑 Authentication Error: Please make sure you have added 'GOOGLE_API_KEY' to your Kaggle secrets. Details: {e}")
# Out:
# ✅ Gemini API key setup complete.

# %%
from google.adk.agents import Agent, SequentialAgent, ParallelAgent, LoopAgent
from google.adk.runners import InMemoryRunner
from google.adk.tools import AgentTool, FunctionTool, google_search
from google.genai import types

print("✅ ADK components imported successfully.")
# Out:
# ✅ ADK components imported successfully.

# %%
# Research Agent: Its job is to use the google_search tool and present findings.
research_agent = Agent(
    name="ResearchAgent",
    model="gemini-2.5-flash-lite",
    instruction="""You are a specialized research agent. Your only job is to use the
    google_search tool to find 2-3 pieces of relevant information on the given topic and present the findings with citations.""",
    tools=[google_search],
    output_key="research_findings", # The result of this agent will be stored in the session state with this key.
)

print("✅ research_agent created.")
# Out:
# ✅ research_agent created.

# %%
# Summarizer Agent: Its job is to summarize the text it receives.
summarizer_agent = Agent(
    name="SummarizerAgent",
    model="gemini-2.5-flash-lite",
    # The instruction is modified to request a bulleted list for a clear output format.
    instruction="""Read the provided research findings: {research_findings}
Create a concise summary as a bulleted list with 3-5 key points.""",
    output_key="final_summary",
)

print("✅ summarizer_agent created.")
# Out:
# ✅ summarizer_agent created.

# %%
# Root Coordinator: Orchestrates the workflow by calling the sub-agents as tools.
root_agent = Agent(
    name="ResearchCoordinator",
    model="gemini-2.5-flash-lite",
    # This instruction tells the root agent HOW to use its tools (which are the other agents).
    instruction="""You are a research coordinator. Your goal is to answer the user's query by orchestrating a workflow.
1. First, you MUST call the `ResearchAgent` tool to find relevant information on the topic provided by the user.
2. Next, after receiving the research findings, you MUST call the `SummarizerAgent` tool to create a concise summary.
3. Finally, present the final summary clearly to the user as your response.""",
    # We wrap the sub-agents in `AgentTool` to make them callable tools for the root agent.
    tools=[
        AgentTool(research_agent),
        AgentTool(summarizer_agent)
    ],
)

print("✅ root_agent created.")
# Out:
# ✅ root_agent created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug("What are the latest advancements in quantum computing and what do they mean for AI?")
# Out:
#  ### Created new session: debug_session_id
#
# User > What are the latest advancements in quantum computing and what do they mean for AI?
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# ResearchCoordinator > The latest advancements in quantum computing are poised to revolutionize AI by significantly enhancing its performance and efficiency. Quantum computers can process massive amounts of data and explore numerous solutions concurrently, leading to faster AI training and more complex models. This leap in computational power is expected to enable AI to tackle currently insurmountable problems in fields such as drug discovery, materials science, logistics optimization, and natural language processing.
#
# In the near future, we'll likely see hybrid systems combining the strengths of both quantum and classical computers. Simultaneously, progress in quantum hardware, including more stable qubits and improved error correction, is crucial and actively being pursued. Interestingly, AI is also contributing to the advancement of quantum computing itself, particularly in areas like error correction.
#
# While the fusion of quantum computing and AI holds immense promise, it's important to acknowledge that the field is still developing. Current challenges include efficiently processing very large datasets and improving input/output speeds. Nonetheless, the ongoing progress and investment suggest that Quantum AI is set to become a transformative force in the coming decade.

# %%
# Outline Agent: Creates the initial blog post outline.
outline_agent = Agent(
    name="OutlineAgent",
    model="gemini-2.5-flash-lite",
    instruction="""Create a blog outline for the given topic with:
    1. A catchy headline
    2. An introduction hook
    3. 3-5 main sections with 2-3 bullet points for each
    4. A concluding thought""",
    output_key="blog_outline", # The result of this agent will be stored in the session state with this key.
)

print("✅ outline_agent created.")
# Out:
# ✅ outline_agent created.

# %%
# Writer Agent: Writes the full blog post based on the outline from the previous agent.
writer_agent = Agent(
    name="WriterAgent",
    model="gemini-2.5-flash-lite",
    # The `{blog_outline}` placeholder automatically injects the state value from the previous agent's output.
    instruction="""Following this outline strictly: {blog_outline}
    Write a brief, 200 to 300-word blog post with an engaging and informative tone.""",
    output_key="blog_draft", # The result of this agent will be stored with this key.
)

print("✅ writer_agent created.")
# Out:
# ✅ writer_agent created.

# %%
# Editor Agent: Edits and polishes the draft from the writer agent.
editor_agent = Agent(
    name="EditorAgent",
    model="gemini-2.5-flash-lite",
    # This agent receives the `{blog_draft}` from the writer agent's output.
    instruction="""Edit this draft: {blog_draft}
    Your task is to polish the text by fixing any grammatical errors, improving the flow and sentence structure, and enhancing overall clarity.""",
    output_key="final_blog", # This is the final output of the entire pipeline.
)

print("✅ editor_agent created.")
# Out:
# ✅ editor_agent created.

# %%
root_agent = SequentialAgent(
    name="BlogPipeline",
    sub_agents=[outline_agent, writer_agent, editor_agent],
)

print("✅ Sequential Agent created.")
# Out:
# ✅ Sequential Agent created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug("Write a blog post about the benefits of multi-agent systems for software developers")
# Out:
#  ### Created new session: debug_session_id
#
# User > Write a blog post about the benefits of multi-agent systems for software developers
# OutlineAgent > Here's a blog outline on the benefits of multi-agent systems for software developers:
#
# ## Blog Outline: Multi-Agent Systems for Software Developers
#
# **Headline:** Unleash Superpowers: How Multi-Agent Systems Will Revolutionize Your Development Workflow
#
# **Introduction Hook:** Tired of monolithic codebases that are a nightmare to maintain? Do you dream of software that can intelligently adapt, learn, and collaborate? Get ready to explore the exciting world of Multi-Agent Systems (MAS) – a paradigm shift that's not just for AI researchers anymore. For software developers, MAS offers a powerful new toolkit to build more robust, scalable, and intelligent applications.
#
# ---
#
# **Main Section 1: Enhanced Modularity and Maintainability**
#
# *   **Breaking Down Complexity:** MAS naturally encourages the decomposition of large, intricate problems into smaller, independent, and self-contained units (agents). This means each agent has a specific responsibility, making your codebase easier to understand, debug, and update.
# *   **Independent Development and Testing:** Developers can focus on building and testing individual agents in isolation. This parallel development stream significantly speeds up the development cycle and reduces the risk of introducing system-wide bugs.
# *   **Graceful Degradation and Resilience:** If one agent fails, the system doesn't necessarily collapse. Other agents can often compensate or take over, leading to more robust applications that can withstand partial failures.
#
# **Main Section 2: Scalability and Distribution Made Easy**
#
# *   **Natural Fit for Distributed Computing:** MAS are inherently designed for distributed environments. Adding more processing power simply means deploying more agents, making it straightforward to scale your application horizontally to handle increased load.
# *   **Resource Optimization:** Agents can be intelligently distributed across different hardware or cloud resources, optimizing performance and cost by placing them where they can execute most efficiently.
# *   **Dynamic Load Balancing:** Agents can communicate and negotiate to distribute tasks dynamically, ensuring that no single agent becomes a bottleneck and that resources are utilized optimally at all times.
#
# **Main Section 3: Intelligence and Adaptability at Scale**
#
# *   **Emergent Behavior and Complex Solutions:** By defining simple rules for individual agents, you can achieve surprisingly complex and intelligent behaviors at the system level. This "emergent intelligence" can tackle problems that are difficult to program explicitly.
# *   **Learning and Adaptation:** Agents can be designed to learn from their environment and interactions, allowing your software to adapt to changing conditions, user behaviors, and new data without requiring constant manual reprogramming.
# *   **Collaborative Problem Solving:** MAS excels at scenarios where multiple entities need to cooperate to achieve a common goal. Think of agents negotiating prices, coordinating delivery routes, or collectively analyzing data.
#
# ---
#
# **Concluding Thought:** Multi-Agent Systems are no longer a niche academic concept. They represent a powerful and practical approach for software developers to build the next generation of intelligent, resilient, and scalable applications. By embracing the principles of modularity, distribution, and emergent intelligence, you can equip yourself and your team with the tools to tackle increasingly complex challenges and deliver truly innovative software solutions. Are you ready to explore the potential of your own development "team"?
# WriterAgent > ## Unleash Superpowers: How Multi-Agent Systems Will Revolutionize Your Development Workflow
#
# Tired of monolithic codebases that are a nightmare to maintain? Do you dream of software that can intelligently adapt, learn, and collaborate? Get ready to explore the exciting world of Multi-Agent Systems (MAS) – a paradigm shift that's not just for AI researchers anymore. For software developers, MAS offers a powerful new toolkit to build more robust, scalable, and intelligent applications.
#
# One of the most immediate benefits of MAS is **enhanced modularity and maintainability**. MAS naturally encourages breaking down complex problems into smaller, independent agents, each with a specific responsibility. This means easier understanding, debugging, and updating of your codebase. Developers can even work on and test individual agents in isolation, speeding up development cycles and reducing bug risks. Plus, if one agent falters, the system can often degrade gracefully, demonstrating impressive resilience.
#
# Beyond maintainability, MAS are a natural fit for **scalability and distribution**. Designed for distributed environments, adding more processing power simply means deploying more agents, allowing for effortless horizontal scaling. Agents can be strategically placed across resources for optimal performance and cost-efficiency, and they can dynamically balance loads, preventing bottlenecks.
#
# Finally, MAS unlocks incredible **intelligence and adaptability at scale**. Simple agent rules can lead to complex, emergent behaviors, solving problems that are hard to program explicitly. Agents can learn from their environment, allowing your software to adapt to changing conditions without constant reprogramming. MAS also excels at collaborative problem-solving, enabling entities to cooperate on tasks like negotiation or coordinated analysis.
#
# Multi-Agent Systems are a practical, powerful approach for building the next generation of software. By embracing modularity, distribution, and emergent intelligence, you can tackle complex challenges and deliver truly innovative solutions. Ready to explore the potential of your own development "team"?
# EditorAgent > ## Unleash Superpowers: How Multi-Agent Systems Will Revolutionize Your Development Workflow
#
# Are you tired of wrestling with monolithic codebases that are a nightmare to maintain? Do you dream of software that can intelligently adapt, learn, and collaborate on its own? If so, get ready to dive into the exciting world of Multi-Agent Systems (MAS). This isn't just a concept for AI researchers anymore; for software developers, MAS offers a powerful new toolkit to build more robust, scalable, and intelligent applications.
#
# ### Enhanced Modularity and Maintainability: Break Free from Complexity
#
# One of the most immediate benefits of MAS is **enhanced modularity and maintainability**. MAS naturally encourages breaking down complex problems into smaller, independent agents, each with a specific responsibility. This makes your codebase significantly easier to understand, debug, and update. Developers can work on and test individual agents in isolation, which drastically speeds up development cycles and reduces the risk of introducing system-wide bugs. Moreover, if one agent falters, the system can often degrade gracefully, demonstrating impressive resilience.
#
# ### Scalability and Distribution Made Effortless
#
# Beyond maintainability, MAS are a natural fit for **scalability and distribution**. Designed with distributed environments in mind, adding more processing power simply means deploying more agents. This allows for effortless horizontal scaling to handle increasing demands. Agents can be strategically placed across various resources for optimal performance and cost-efficiency, and they can dynamically balance loads, effectively preventing bottlenecks.
#
# ### Intelligence and Adaptability at Scale
#
# Finally, MAS unlocks incredible **intelligence and adaptability at scale**. Simple agent rules can lead to complex, emergent behaviors, enabling you to solve problems that are difficult to program explicitly. Agents can learn from their environment and interactions, allowing your software to adapt to changing conditions without constant reprogramming. MAS also excels at collaborative problem-solving, enabling entities to cooperate on tasks like negotiation or coordinated analysis.
#
# Multi-Agent Systems represent a practical and powerful approach for building the next generation of software. By embracing modularity, distribution, and emergent intelligence, you can tackle complex challenges and deliver truly innovative solutions. Are you ready to explore the potential of your own development "team"?

# %%
# Tech Researcher: Focuses on AI and ML trends.
tech_researcher = Agent(
    name="TechResearcher",
    model="gemini-2.5-flash-lite",
    instruction="""Research the latest AI/ML trends. Include 3 key developments,
the main companies involved, and the potential impact. Keep the report very concise (100 words).""",
    tools=[google_search],
    output_key="tech_research", # The result of this agent will be stored in the session state with this key.
)

print("✅ tech_researcher created.")
# Out:
# ✅ tech_researcher created.

# %%
# Health Researcher: Focuses on medical breakthroughs.
health_researcher = Agent(
    name="HealthResearcher",
    model="gemini-2.5-flash-lite",
    instruction="""Research recent medical breakthroughs. Include 3 significant advances,
their practical applications, and estimated timelines. Keep the report concise (100 words).""",
    tools=[google_search],
    output_key="health_research", # The result will be stored with this key.
)

print("✅ health_researcher created.")
# Out:
# ✅ health_researcher created.

# %%
# Finance Researcher: Focuses on fintech trends.
finance_researcher = Agent(
    name="FinanceResearcher",
    model="gemini-2.5-flash-lite",
    instruction="""Research current fintech trends. Include 3 key trends,
their market implications, and the future outlook. Keep the report concise (100 words).""",
    tools=[google_search],
    output_key="finance_research", # The result will be stored with this key.
)

print("✅ finance_researcher created.")
# Out:
# ✅ finance_researcher created.

# %%
# The AggregatorAgent runs *after* the parallel step to synthesize the results.
aggregator_agent = Agent(
    name="AggregatorAgent",
    model="gemini-2.5-flash-lite",
    # It uses placeholders to inject the outputs from the parallel agents, which are now in the session state.
    instruction="""Combine these three research findings into a single executive summary:

    **Technology Trends:**
    {tech_research}
    
    **Health Breakthroughs:**
    {health_research}
    
    **Finance Innovations:**
    {finance_research}
    
    Your summary should highlight common themes, surprising connections, and the most important key takeaways from all three reports. The final summary should be around 200 words.""",
    output_key="executive_summary", # This will be the final output of the entire system.
)

print("✅ aggregator_agent created.")
# Out:
# ✅ aggregator_agent created.

# %%
# The ParallelAgent runs all its sub-agents simultaneously.
parallel_research_team = ParallelAgent(
    name="ParallelResearchTeam",
    sub_agents=[tech_researcher, health_researcher, finance_researcher],
)

# This SequentialAgent defines the high-level workflow: run the parallel team first, then run the aggregator.
root_agent = SequentialAgent(
    name="ResearchSystem",
    sub_agents=[parallel_research_team, aggregator_agent],
)

print("✅ Parallel and Sequential Agents created.")
# Out:
# ✅ Parallel and Sequential Agents created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug("Run the daily executive briefing on Tech, Health, and Finance")
# Out:
#  ### Created new session: debug_session_id
#
# User > Run the daily executive briefing on Tech, Health, and Finance
# TechResearcher > **AI/ML Trends Report - November 10, 2025**
#
# **Key Developments:**
#
# 1.  **Generative AI Expansion:** Generative AI is moving beyond text to create complex multimedia content like graphics, video, and music. This trend is projected for significant growth, enhancing creative industries and practical applications.
# 2.  **Shift to Smaller, Specialized Models (SLMs):** While Large Language Models (LLMs) remain influential, there's a growing trend towards Smaller, specialized Language Models (SLMs) that offer improved efficiency and performance for specific tasks.
# 3.  **Democratization and Accessibility:** AI tools are becoming more user-friendly and accessible to a wider audience, not just experts. Platforms like OpenAI's GPT-4 and Google's AutoML are enabling individuals and smaller businesses to leverage AI with minimal technical knowledge.
#
# **Main Companies Involved:**
#
# *   **Generative AI:** OpenAI (GPT models), Google (Imagen, Muse), Synthesia, Runway ML, Stability AI.
# *   **SLMs & Accessibility:** Google (AutoML), OpenAI, Microsoft.
# *   **Broader AI/ML Development:** NVIDIA (GPUs for training), IBM (Watson), Amazon (AWS), Apple, Meta, Microsoft.
#
# **Potential Impact:**
#
# These trends are driving significant business growth, improving operational efficiency, and unlocking new revenue streams. The increased accessibility fosters innovation and broader AI adoption across various sectors like healthcare and finance. However, ethical considerations, data privacy, and workforce adaptation remain crucial challenges to navigate.
# FinanceResearcher > Here's your daily executive briefing for November 10, 2025:
#
# **Technology:**
# The tech landscape in November 2025 is dominated by AI advancements, particularly "agentic AI" and "context engineering," enabling AI to perform complex tasks autonomously. This surge in AI is driving massive infrastructure spending, requiring sophisticated orchestration of GPUs. Emerging tech trends like 5G expansion, quantum computing, and green energy continue to gain momentum, reshaping industries. Despite innovation, the sector faces significant layoffs, with over 100,000 positions eliminated in 2025.
#
# **Health:**
# Healthcare in 2025 is increasingly personalized and technology-driven. Wearable tech is evolving towards brain-computer interfaces and implants, promising solutions for various medical conditions, though raising ethical concerns. AI and data are central to tailored wellness plans and communication strategies. Mental healthcare is being revolutionized by VR/AR sessions and AI-powered chatbots. Consumers are also prioritizing gut health and functional foods for preventative wellness, with a growing focus on healthy aging and cognitive function.
#
# **Finance:**
# Global finance in November 2025 is characterized by mega-mergers, particularly in India's banking sector, aiming for greater efficiency and global competitiveness. Volatility persists in global equity markets, with forecasts of potential corrections, necessitating robust risk assessment skills. A key trend is the deep integration of AI into financial systems for data-backed decision-making. Professionals with a blend of financial modeling and macroeconomic understanding are increasingly in demand. Key economic events, including Federal Reserve policy shifts and inflation data, are closely watched for their market impact.
# HealthResearcher > **Health Breakthroughs:**
#
# 1.  **Gene Therapy for Inherited Diseases:** Advances in gene therapy are enabling the treatment of genetic disorders. For instance, a recent trial successfully restored hearing in a deaf child by introducing functional OTOF genes. This approach holds promise for numerous inherited conditions. Estimated timeline: Ongoing development, with wider clinical applications expected in the next 5-10 years.
#
# 2.  **CAR T-Cell Therapy for Brain Cancer:** This groundbreaking therapy, which reengineers a patient's immune cells, is now showing promise in treating brain cancers, including glioblastoma in adults and pediatric brain tumors. Estimated timeline: Further trials and broader adoption are anticipated within the next 5 years.
#
# 3.  **Stem Cell Treatment for Vision Restoration:** Researchers are using induced pluripotent stem cells (iPS) to generate corneal cells, successfully restoring vision in patients with corneal epithelial stem cell deficiency. Larger clinical trials are planned, with potential for treating other eye diseases. Estimated timeline: Widespread application for certain eye conditions could be seen in 3-5 years.
#
# **Technology Breakthroughs:**
#
# 1.  **Agentic AI:** Autonomous AI agents capable of executing complex tasks independently are emerging, set to reshape industries from manufacturing to customer service. By 2028, a significant portion of generative AI interactions will involve these action models. Estimated timeline: Increasing integration into various sectors over the next 3-5 years.
#
# 2.  **Post-Quantum Cryptography (PQC):** As quantum computing advances, PQC is crucial for securing data against future threats. Progress in developing quantum-resistant algorithms is ongoing, with the market shifting focus to these solutions. Estimated timeline: Transition and adoption of PQC standards will likely occur over the next 5-10 years.
#
# 3.  **Spatial Computing and XR:** This merges the physical and digital worlds via AR/VR, IoT, and AI, offering immersive applications in education, retail, and healthcare. The market is projected to grow substantially by 2033. Estimated timeline: Wider consumer and enterprise adoption expected within the next 5-10 years.
#
# **Finance Breakthroughs:**
#
# 1.  **AI and Machine Learning in Risk Decisioning:** AI and ML are being integrated for more sophisticated risk assessment and enhanced user experiences in financial services. This is automating underwriting and enabling real-time decisions. Estimated timeline: Continued deepening of AI/ML integration across all financial operations within the next 1-3 years.
#
# 2.  **Blockchain and Decentralized Finance (DeFi):** Innovations like blockchain-based digital bonds and DeFi protocols are increasing transparency, reducing costs, and offering new models for lending and borrowing. Estimated timeline: Maturation and broader adoption of these technologies are expected within the next 3-7 years.
#
# 3.  **Tokenization and CBDCs:** The tokenization of assets, alongside the development of Central Bank Digital Currencies (CBDCs), promises faster, cheaper, and more secure transactions, especially for cross-border settlements. Estimated timeline: Significant advancements and pilot programs are underway, with wider implementation anticipated in the next 5-10 years.
# AggregatorAgent > ## Executive Summary: November 10, 2025 - AI, Health, and Finance Convergence
#
# **AI is the dominant force shaping all sectors**, driving significant advancements in technology, healthcare, and finance. The expansion of generative AI into multimedia content, alongside the rise of efficient, specialized AI models, is democratizing access and fostering innovation. This AI surge necessitates massive infrastructure investment, even amidst industry layoffs.
#
# **In healthcare**, AI is powering a new era of personalized medicine, from tailored wellness plans and mental health VR/AR to breakthroughs in treating genetic disorders with gene therapy and advanced cancers with CAR T-cell therapy. Stem cell treatments for vision restoration are nearing widespread application.
#
# **Finance is undergoing a profound transformation**, with AI deeply integrated into risk assessment and decision-making, automating underwriting and enabling real-time operations. Concurrent innovations in blockchain, DeFi, tokenization, and CBDCs are enhancing transparency and efficiency, while global markets remain volatile, demanding sophisticated risk management.
#
# **Key takeaways:** AI's pervasive influence is accelerating progress across all fields, promising transformative solutions but also highlighting the critical need for ethical considerations, data privacy, and workforce adaptation. Technologies like agentic AI and spatial computing are set to further reshape industries, while quantum-resistant cryptography will become essential for future security.

# %%
# This agent runs ONCE at the beginning to create the first draft.
initial_writer_agent = Agent(
    name="InitialWriterAgent",
    model="gemini-2.5-flash-lite",
    instruction="""Based on the user's prompt, write the first draft of a short story (around 100-150 words).
    Output only the story text, with no introduction or explanation.""",
    output_key="current_story", # Stores the first draft in the state.
)

print("✅ initial_writer_agent created.")
# Out:
# ✅ initial_writer_agent created.

# %%
# This agent's only job is to provide feedback or the approval signal. It has no tools.
critic_agent = Agent(
    name="CriticAgent",
    model="gemini-2.5-flash-lite",
    instruction="""You are a constructive story critic. Review the story provided below.
    Story: {current_story}
    
    Evaluate the story's plot, characters, and pacing.
    - If the story is well-written and complete, you MUST respond with the exact phrase: "APPROVED"
    - Otherwise, provide 2-3 specific, actionable suggestions for improvement.""",
    output_key="critique", # Stores the feedback in the state.
)

print("✅ critic_agent created.")
# Out:
# ✅ critic_agent created.

# %%
# This is the function that the RefinerAgent will call to exit the loop.
def exit_loop():
    """Call this function ONLY when the critique is 'APPROVED', indicating the story is finished and no more changes are needed."""
    return {"status": "approved", "message": "Story approved. Exiting refinement loop."}

print("✅ exit_loop function created.")
# Out:
# ✅ exit_loop function created.

# %%
# This agent refines the story based on critique OR calls the exit_loop function.
refiner_agent = Agent(
    name="RefinerAgent",
    model="gemini-2.5-flash-lite",
    instruction="""You are a story refiner. You have a story draft and critique.
    
    Story Draft: {current_story}
    Critique: {critique}
    
    Your task is to analyze the critique.
    - IF the critique is EXACTLY "APPROVED", you MUST call the `exit_loop` function and nothing else.
    - OTHERWISE, rewrite the story draft to fully incorporate the feedback from the critique.""",
    
    output_key="current_story", # It overwrites the story with the new, refined version.
    tools=[FunctionTool(exit_loop)], # The tool is now correctly initialized with the function reference.
)

print("✅ refiner_agent created.")
# Out:
# ✅ refiner_agent created.

# %%
# The LoopAgent contains the agents that will run repeatedly: Critic -> Refiner.
story_refinement_loop = LoopAgent(
    name="StoryRefinementLoop",
    sub_agents=[critic_agent, refiner_agent],
    max_iterations=2, # Prevents infinite loops
)

# The root agent is a SequentialAgent that defines the overall workflow: Initial Write -> Refinement Loop.
root_agent = SequentialAgent(
    name="StoryPipeline",
    sub_agents=[initial_writer_agent, story_refinement_loop],
)

print("✅ Loop and Sequential Agents created.")
# Out:
# ✅ Loop and Sequential Agents created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug("Write a short story about a lighthouse keeper who discovers a mysterious, glowing map")
# Out:
#  ### Created new session: debug_session_id
#
# User > Write a short story about a lighthouse keeper who discovers a mysterious, glowing map
# InitialWriterAgent > Elias, keeper of the Black Rock Lighthouse for thirty years, traced the salt-worn grooves of the stone floor. The storm raged outside, a familiar symphony of wind and wave. Then, a shimmer. Tucked into a crevice he’d sworn was empty, lay a rolled parchment. It wasn't paper, but something that felt like dried kelp, cool and slick. As he unfurled it, a soft, ethereal blue light pulsed from within. Strange symbols, unlike any he knew, glowed, illuminating a path across the parchment. It depicted not land or sea, but currents of starlight and nebulous shores. A map, he realized, to somewhere far beyond the horizon. His heart, usually as steady as the beam from his tower, began to race.
# CriticAgent > CriticAgent:
#
# The story introduces an intriguing premise with Elias, the seasoned lighthouse keeper, and the discovery of a celestial map. However, there are a few areas that could be strengthened to make the narrative more compelling.
#
# 1.  **Show, Don't Just Tell Elias's Routine:** While it's mentioned Elias has been the keeper for thirty years, we don't get a strong sense of his daily life or his connection to the lighthouse. Briefly describing a mundane task, the familiar sounds of the storm, or a sensory detail specific to his solitary existence before the discovery would create a more vivid contrast with the extraordinary event that follows.
# 2.  **Expand on the Map's Mystery:** The description of the map is evocative, but it could benefit from more sensory detail or a hint at its potential purpose or origin. What does the "dried kelp" feel like beyond cool and slick? Are there any discernible patterns or shapes within the starlight currents that Elias might try to interpret, even if he doesn't understand them? This would deepen the reader's curiosity.
# 3.  **Enhance Elias's Reaction:** Elias's heart racing is a good start, but his reaction could be more nuanced. Given thirty years of solitude and routine, this discovery is monumental. Consider adding a moment of disbelief, a physical action like dropping the map, or a thought that directly questions his reality or sanity. This would make his internal shift more palpable.
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# CriticAgent > APPROVED
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
